# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
nba_data_temp = pd.read_csv('nba_playoff_finals.csv')
nba_data_temp = nba_data_temp.dropna(axis=0, how='any')
nba_data = nba_data_temp.drop(['Team ID'], axis=1)

nba_data.head()
# Out:
#     W   L   W/L%  Finish   SRS  Pace  Rel_Pace   ORtg  Rel_ORtg   DRtg  \
# 0  43  39  0.524       2 -1.23  97.4       1.0  104.9      -3.9  105.7
# 1  48  34  0.585       2  3.49  97.1       1.3  105.1      -1.3  101.4
# 2  60  22  0.732       1  4.75  93.9       0.0  108.9       3.3  103.1
# 3  38  44  0.463       4 -0.88  94.6       0.7  105.9      -0.8  106.4
# 4  44  38  0.537       2 -0.08  92.6       0.6  104.8      -1.1  104.4
#
#     ...      FT%   ORB   DRB   TRB   AST  STL   TOV    PF    PTS  Finals
# 0   ...    0.728  10.3  34.1  44.3  23.6  8.2  15.8  18.2  103.2       L
# 1   ...    0.783   8.3  33.8  42.1  25.6  9.1  15.0  19.1  102.8       L
# 2   ...    0.778   8.7  31.8  40.6  25.7  9.1  14.2  17.8  102.5       L
# 3   ...    0.781   8.7  31.3  40.0  24.9  8.3  15.3  19.2  101.0       L
# 4   ...    0.715   9.2  31.6  40.9  24.5  8.1  14.9  18.0   98.0       L
#
# [5 rows x 33 columns]

# %%
# Assign X (data) and z (target)

### BEGIN SOLUTION
X = nba_data.drop("Finals", axis=1)
z = nba_data["Finals"]
print(X.shape, z.shape)
### END SOLUTION
# Out:
# (160, 32) (160,)

# %%
### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, z_train, z_test = train_test_split(X, z, random_state=1, stratify=z)
### END SOLUTION

# %%
### BEGIN SOLUTION
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
### END SOLUTION
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
### BEGIN SOLUTION
classifier.fit(X_train, z_train)
### END SOLUTION
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
### BEGIN SOLUTION
print(f"Training Data Score: {classifier.score(X_train, z_train)}")
print(f"Testing Data Score: {classifier.score(X_test, z_test)}")
### END SOLUTION
# Out:
# Training Data Score: 0.9916666666666667
# Testing Data Score: 0.9

# %%
### BEGIN SOLUTION
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {z_test[:10].tolist()}")
### END SOLUTION
# Out:
# First 10 Predictions:   ['L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'W']
# First 10 Actual labels: ['L', 'L', 'L', 'L', 'L', 'L', 'L', 'W', 'L', 'L']

# %%
nba_2018_temp = pd.read_csv('nba_2018_teams.csv')
nba_2018_temp
# Out:
#                              Team ID   W   L   W/L%  Finish   SRS   Pace  \
# 0           Boston Celtics*2017-2018  55  27  0.671       2  3.23   96.0
# 1      Cleveland Cavaliers*2017-2018  50  32  0.610       1  0.59   98.0
# 2    Golden State Warriors*2017-2018  58  24  0.707       1  5.79   99.6
# 3          Houston Rockets*2017-2018  65  17  0.793       1  8.21   97.6
# 4           Indiana Pacers*2017-2018  48  34  0.585       2  1.18   96.0
# 5               Miami Heat*2017-2018  44  38  0.537       1  0.15   95.6
# 6          Milwaukee Bucks*2017-2018  44  38  0.537       3 -0.45   96.3
# 7     New Orleans Pelicans*2017-2018  48  34  0.585       2  1.48  100.5
# 8    Oklahoma City Thunder*2017-2018  48  34  0.585       2  3.42   96.7
# 9       Philadelphia 76ers*2017-2018  52  30  0.634       3  4.30   99.8
# 10  Portland Trail Blazers*2017-2018  49  33  0.598       1  2.60   96.5
# 11       San Antonio Spurs*2017-2018  47  35  0.573       3  2.89   95.0
# ...

# %%
nba_2018_teams = nba_2018_temp.drop(['Team ID'], axis=1)

# %%
predictions_2018 = classifier.predict(nba_2018_teams)
print(f"First 16 Predictions:   {predictions_2018[:16]}")
# Out:
# First 16 Predictions:   ['L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L']
